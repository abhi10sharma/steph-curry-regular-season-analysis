# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Curry30 regular season.xlsx')
df
# Out:
#           Date     Age   Tm  Opp Unnamed: 4  GS                   MP  FG  FGA  \
# 0   2009-10-28  21-228  GSW  HOU     L (-1)   1  1900-01-01 11:39:00   7   12
# 1   2009-10-30  21-230  GSW  PHO    L (-22)   1  1900-01-01 15:05:00   5    9
# 2   2009-11-04  21-235  GSW  MEM     W (+8)   1  1900-01-01 04:27:00   3    6
# 3   2009-11-06  21-237  GSW  LAC    L (-28)   1             21:32:00   1    5
# 4   2009-11-08  21-239  GSW  SAC    L (-13)   1  1900-01-01 07:15:00   4    8
# ..         ...     ...  ...  ...        ...  ..                  ...  ..  ...
# 694 2019-10-24  31-224  GSW  LAC    L (-19)   1  1900-01-01 05:48:00   8   20
# 695 2019-10-27  31-227  GSW  OKC    L (-28)   1  1900-01-01 06:08:00   7   18
# 696 2019-10-28  31-228  GSW  NOP    W (+11)   1  1900-01-01 07:00:00   9   17
# 697 2019-10-30  31-230  GSW  PHO    L (-11)   1             21:09:00   3   11
# 698 2020-03-05  31-357  GSW  TOR     L (-8)   1  1900-01-01 03:14:00   6   16
#
# ...

# %%
df.isna().sum()
# Out:
# Date          0
# Age           0
# Tm            0
# Opp           0
# Unnamed: 4    0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%           2
# 3P            0
# 3PA           0
# 3P%           4
# FT            0
# FTA           0
# FT%           1
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# GmSc          0
# +/-           0
# dtype: int64

# %%
df.describe()
# Out:
#                GS          FG         FGA         FG%          3P         3PA  \
# count  699.000000  699.000000  699.000000  697.000000  699.000000  699.000000
# mean     0.991416    8.128755   17.068670    0.470719    3.569385    8.210300
# std      0.092316    3.309362    5.146104    0.128132    2.348988    3.756577
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    6.000000   14.000000    0.389000    2.000000    5.000000
# 50%      1.000000    8.000000   17.000000    0.474000    3.000000    8.000000
# 75%      1.000000   10.000000   20.000000    0.556000    5.000000   11.000000
# max      1.000000   20.000000   33.000000    1.000000   13.000000   20.000000
#
#               3P%          FT         FTA         FT%  ...         DRB  \
# count  695.000000  699.000000  699.000000  698.000000  ...  699.000000
# mean     0.422778    3.662375    4.044349    0.773864  ...    3.816881
# ...

# %%
df = df.rename({'Unnamed: 4': 'Win/Loss'}, axis=1)

# %%
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      699 non-null    datetime64[ns]
#  1   Age       699 non-null    object
#  2   Tm        699 non-null    object
#  3   Opp       699 non-null    object
#  4   Win/Loss  699 non-null    object
#  5   GS        699 non-null    int64
#  6   MP        699 non-null    object
#  7   FG        699 non-null    int64
#  8   FGA       699 non-null    int64
#  9   FG%       697 non-null    float64
#  10  3P        699 non-null    int64
#  11  3PA       699 non-null    int64
#  12  3P%       695 non-null    float64
#  13  FT        699 non-null    int64
#  14  FTA       699 non-null    int64
#  15  FT%       698 non-null    float64
#  16  ORB       699 non-null    int64
#  17  DRB       699 non-null    int64
#  18  TRB       699 non-null    int64
#  19  AST       699 non-null    int64
# ...

# %%
# df['W/L'] = df['W/L'].astype(str)

# %%
df['Win/Loss'] = df['Win/Loss'].apply(lambda x: x.split('(')[0])

# %%
df
# Out:
#           Date     Age   Tm  Opp Win/Loss  GS                   MP  FG  FGA  \
# 0   2009-10-28  21-228  GSW  HOU       L    1  1900-01-01 11:39:00   7   12
# 1   2009-10-30  21-230  GSW  PHO       L    1  1900-01-01 15:05:00   5    9
# 2   2009-11-04  21-235  GSW  MEM       W    1  1900-01-01 04:27:00   3    6
# 3   2009-11-06  21-237  GSW  LAC       L    1             21:32:00   1    5
# 4   2009-11-08  21-239  GSW  SAC       L    1  1900-01-01 07:15:00   4    8
# ..         ...     ...  ...  ...      ...  ..                  ...  ..  ...
# 694 2019-10-24  31-224  GSW  LAC       L    1  1900-01-01 05:48:00   8   20
# 695 2019-10-27  31-227  GSW  OKC       L    1  1900-01-01 06:08:00   7   18
# 696 2019-10-28  31-228  GSW  NOP       W    1  1900-01-01 07:00:00   9   17
# 697 2019-10-30  31-230  GSW  PHO       L    1             21:09:00   3   11
# 698 2020-03-05  31-357  GSW  TOR       L    1  1900-01-01 03:14:00   6   16
#
# ...

# %% [markdown]
# # Win Vs Loss

# %%
df.loc[df['Opp'] == 'HOU'].count()
# loss = df.loc[df['W/L'] == 'L'].count()
# loss
# Out:
# Date        30
# Age         30
# Tm          30
# Opp         30
# Win/Loss    30
# GS          30
# MP          30
# FG          30
# FGA         30
# FG%         30
# 3P          30
# 3PA         30
# 3P%         30
# FT          30
# FTA         30
# FT%         30
# ORB         30
# DRB         30
# TRB         30
# AST         30
# STL         30
# BLK         30
# TOV         30
# PF          30
# PTS         30
# GmSc        30
# +/-         30
# dtype: int64

# %%
df.loc[df['Win/Loss'] == "L"]
# Out:
# Empty DataFrame
# Columns: [Date, Age, Tm, Opp, Win/Loss, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, GmSc, +/-]
# Index: []
#
# [0 rows x 27 columns]

# %%
res_df = df.groupby(['Win/Loss']).count()
res_df
# Out:
#           Date  Age   Tm  Opp   GS   MP   FG  FGA  FG%   3P  ...  DRB  TRB  \
# Win/Loss                                                     ...
# L          236  236  236  236  236  236  236  236  236  236  ...  236  236
# W          463  463  463  463  463  463  463  463  461  463  ...  463  463
#
#           AST  STL  BLK  TOV   PF  PTS  GmSc  +/-
# Win/Loss
# L         236  236  236  236  236  236   236  236
# W         463  463  463  463  463  463   463  463
#
# [2 rows x 26 columns]

# %%
# result = [res for Win/Loss, df in df.groupby(['Win/Loss'])]
loss = res_df.iloc[0][0]
win = res_df.iloc[1][0]

label = ['Loss', 'Win']
color = ['#7aff8c', '#0cf05c']

plt.figure(figsize=(6,3), dpi = 150)
plt.pie([loss, win], labels = label, colors = color, autopct = '%.2f%%')

plt.show
plt.savefig('win_vs_loss.png')

# %%
res_df.iloc[1][0]
# Out:
# 463

# %% [markdown]
# # Curry's Age Wise Stats Comparison

# %%
df['Age'] = df['Age'].apply(lambda x: x.split('-')[0])
df
# Out:
#           Date Age   Tm  Opp Win/Loss  GS                   MP  FG  FGA  \
# 0   2009-10-28  21  GSW  HOU       L    1  1900-01-01 11:39:00   7   12
# 1   2009-10-30  21  GSW  PHO       L    1  1900-01-01 15:05:00   5    9
# 2   2009-11-04  21  GSW  MEM       W    1  1900-01-01 04:27:00   3    6
# 3   2009-11-06  21  GSW  LAC       L    1             21:32:00   1    5
# 4   2009-11-08  21  GSW  SAC       L    1  1900-01-01 07:15:00   4    8
# ..         ...  ..  ...  ...      ...  ..                  ...  ..  ...
# 694 2019-10-24  31  GSW  LAC       L    1  1900-01-01 05:48:00   8   20
# 695 2019-10-27  31  GSW  OKC       L    1  1900-01-01 06:08:00   7   18
# 696 2019-10-28  31  GSW  NOP       W    1  1900-01-01 07:00:00   9   17
# 697 2019-10-30  31  GSW  PHO       L    1             21:09:00   3   11
# 698 2020-03-05  31  GSW  TOR       L    1  1900-01-01 03:14:00   6   16
#
#        FG%  ...  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# ...

# %%
age_df = df.groupby(['Age']).sum()
age_df
# Out:
#      GS   FG   FGA     FG%   3P  3PA     3P%   FT  FTA     FT%  ...  DRB  TRB  \
# Age                                                             ...
# 21   62  399   871  28.678  123  293  25.093  135  153  38.567  ...  239  274
# 22   73  529  1098  34.715  156  352  31.193  217  234  54.786  ...  252  299
# 23   39  250   523  18.968   93  198  18.089   75   87  24.470  ...  124  157
# 24   62  480  1075  27.563  203  446  27.169  213  235  49.409  ...  202  248
# 25   79  655  1421  36.104  270  646  32.043  289  332  62.778  ...  291  342
# 26   77  648  1322  37.579  268  620  32.813  311  341  62.290  ...  280  332
# 27   80  786  1543  40.185  396  841  36.563  362  396  63.938  ...  329  395
# 28   81  705  1516  37.595  333  827  31.801  334  366  68.607  ...  325  389
# 29   65  555  1122  31.674  284  649  27.771  329  364  53.565  ...  274  320
# 30   57  535  1126  27.070  287  670  23.996  232  252  49.258  ...  264  302
# ...

# %%
plt.figure(figsize=(6,4), dpi = 150)

age = [Age for Age, df in df.groupby(['Age'])]

plt.bar(age, age_df['3P'], color = '#e1fc47', edgecolor = 'Black')

plt.title('3-P Comparison by Age', fontsize = 20)

plt.xticks(age)


plt.xlabel('Age', fontsize = 15)
plt.ylabel('Total 3-Pointers', fontsize = 15)

plt.savefig('3P_comparison.png')
plt.show()

# %% [markdown]
# # Curry's Stats Comparison Against All Teams

# %%
opp_df = df.groupby(['Opp']).sum().sort_values('PTS', ascending = False)
opp_df
# Out:
#      GS   FG  FGA     FG%   3P  3PA     3P%   FT  FTA     FT%  ...  DRB  TRB  \
# Opp                                                            ...
# LAC  38  304  604  18.302  144  308  17.203  184  202  32.224  ...  160  183
# OKC  34  302  624  16.547  118  278  14.760  121  136  26.961  ...  138  168
# PHO  37  287  606  17.313  129  296  15.881  109  125  28.338  ...  132  160
# POR  30  277  579  13.960  126  272  13.421  122  138  23.919  ...  103  129
# MIN  30  268  553  14.465  109  255  11.798  110  121  24.332  ...  119  148
# MEM  30  263  546  14.884  122  270  13.970  103  109  19.213  ...  126  151
# SAC  33  249  539  14.762  120  281  13.204  120  135  26.936  ...  139  162
# HOU  30  246  524  14.064   95  238  11.521  107  125  21.923  ...  111  135
# DEN  31  238  492  14.969  118  258  14.796   81   92  18.495  ...  112  127
# DAL  30  227  488  13.653  107  240  12.538  110  120  24.250  ...  105  126
# ...

# %%
plt.figure(figsize=(7,4), dpi = 300)

team = [Opp for Opp, df in df.groupby(['Opp'])]

plt.bar(team, opp_df['PTS'], color = '#44e3a9', edgecolor = 'Black')

plt.title('Team Against Scored Most Point', fontsize = 20)

plt.xticks(team, rotation = 'vertical')


plt.xlabel('Team', fontsize = 15)
plt.ylabel('Total Points Made', fontsize = 15)

plt.savefig('team_wise_comparison.png')
plt.show()
